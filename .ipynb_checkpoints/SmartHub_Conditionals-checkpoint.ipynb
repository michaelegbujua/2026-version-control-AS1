# %% [markdown]
# 1. Write a program that takes a number as input and prints whether it's positive, negative, or zero.

# %%
num= int(input('enter a value: '))
if num>0:
    print(f"{num} is a positive value")
elif num ==0:
    print(f"{num} is a neutral value")
else:
    print(f"{num} is a negative value")
# Out:
# enter a value:  0
# 0 is a neutral value

# %% [markdown]
# 2. Write a program that determines if a year entered by the user is a leap year. (Hint: A leap year is divisible by 4,
# except for century years which must be divisible by 400).

# %%
year = int(input('enter a year: '))
if year%4==0:
    print(f"{year} is a leap year")
elif year%400==0:
    print(f"{year} is a century year")
else:
    print(f"{year} is not a leap year")
# Out:
# enter a year:  2023
# 2023 is not a leap year

# %% [markdown]
# 3. Create a program that compares two numbers and prints whether the first number is greater than, less than, or equal to the second number.

# %%
a= 3
b= 8
if a==b:
    print("the values are equal")
elif a>b:
    print(f"{a} is greater than {b}")
else:
    print(f"{a} is less than {b}")
# Out:
# 3 is less than 8

# %% [markdown]
# 4. Write a program that checks if a number is both greater than 10 and less than 100. If it’s , it should print “Great!!”, else print “Nah!!”

# %%
num = int(input('enter value'))
if num in range(10,101):
    print("Great")
else:
    print("Nah!")
# Out:
# enter value 4
# Nah!

# %% [markdown]
# 5. Create a simple calculator that takes two numbers and an operator (+, -, *, /) as input and performs the corresponding operation.

# %%
a= 9
b= 2
sum_ab= a + b
sub_ab= a - b
mult_ab= a * b
div_ab = a/b
print(f" sum: {sum_ab} \n difference: {sub_ab} \n product: {mult_ab} \n divide: {div_ab}")
# Out:
#  sum: 11
#  difference: 7
#  product: 18
#  divide: 4.5

# %% [markdown]
# 6. Write a program that categorizes a person by age: child (0-12), teenager (13-19), adult (20-64), or senior (65+)

# %%
age = int(input('enter age'))
if age in range(0,13):
    print("Child")
elif age in range(13,20):
    print("Teenager")
elif age in range(20,65):
    print('Adult')
else:
    print('Senior citizens')
# Out:
# enter age 46
# Adult

# %% [markdown]
# 7. Create a program that determines if a triangle is equilateral (all sides equal), isosceles (two sides equal), or scalene (no sides equal) based on three side lengths.

# %%
side1 = int(input("enter the first side of the triangle"))
side2 = int(input("enter the second side of the triangle"))
side3 = int(input("enter the third side of the triangle"))

if side1<=0 or side2<= 0 or side3 <= 0:
    print('Invalid length')
elif side1==side2 and side2==side3:
    print("Its an EQUILATERAL TRIANGLE")
elif side1!=side2 and side2!=side3:
    print("Its a SCALENE TRIANGLE")
else:
    print("Its an ISOSOLES TRIANGLE")
# Out:
# enter the first side of the triangle 4
# enter the second side of the triangle 3
# enter the third side of the triangle 1
# Its a SCALENE TRIANGLE

# %% [markdown]
# 8. Write a program that checks if two strings entered by the user are exactly equal (case-sensitive).

# %%
word1 =input('enter the first word')
word2 =input('enter the second word')
if word1==word2:
    print('They are identical')
else:
    print(f" {word1} and {word2} are different")
# Out:
# enter the first word MAP
# enter the second word MAp
#  MAP and MAp are different

# %% [markdown]
# 9. Create a program that compares two strings ignoring case and prints whether they are the same or different.

# %%
word1 =input('enter the first word').lower()
word2 =input('enter the second word').lower()
if word1==word2:
    print('They are the same')
else:
    print(f" {word1} and {word2} are different")
# Out:
# enter the first word MAP
# enter the second word Map
# They are identical

# %% [markdown]
# 10. Write a program that checks if a password meets basic criteria: at least 8 characters long and not equal to "password" or "123456".

# %%
psword =input('enter your password')
if len(psword)<8:
    print('Password must be at least 8-character long')
elif psword=="password":
    print("The keyword 'password' is reserved for your security")
elif psword =='123456':
    print('the password entered is guessable')
else:
    print('password saved')
# Out:
# enter your password wedin
# Password must be at least 8-character long

# %% [markdown]
# 11. Create a program that categorizes a word as "short" (1-4 letters), "medium" (5-8 letters), or "long" (9+ letters).

# %%
word = input('enter a word:')
if len(word)<=4:
    print(f"{word} is Short")
elif len(word) in range(5,9):
    print(f" {word} is medium")
    
else:
    print(f"{word} is long")
# Out:
# enter a word:general
#  general is medium
